# %%
# %pylab inline
from scipy import signal
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
b = signal.firwin(80, 125/500, window=('kaiser', 8), nyq=500)
w, h = signal.freqz(b)

# %%
plt.plot(w, 20 * np.log10(abs(h)), 'b')

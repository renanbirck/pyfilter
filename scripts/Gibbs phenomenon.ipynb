# %%
# %pylab inline
import matplotlib.pyplot as plt
import numpy as np, scipy as sp

# Forçar o uso de LaTeX
from matplotlib import rc
##rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
## for Palatino and other serif fonts use:
rc('font',**{'family':'serif','serif':['Palatino']})
rc('text', usetex=True)
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 

def sum_of_sine(N, x):
    """ Calculates \sum_{i = 1}{N} sin([2*i + 1] x)/(2i+1) for given N, x."""
    
    pts = np.arange(1, N+1, 2) # Odd points
    return sum(np.sin(pts * x)/pts)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.figure(1, figsize=(12,9))
plt.xlim([0, 2*np.pi])
plt.ylim([-1.1, 1.1])
plt.grid()
xvals = np.arange(0, 2*np.pi, 0.001)
plt.axvline(np.pi)
vals = [20, 200, 500]
for pos, N in enumerate(vals):
    plot(xvals, [sum_of_sine(N, x) for x in xvals], color=['red', 'magenta', 'indigo'][pos])
legend(map(lambda x: "N = {}".format(x), vals), loc='best')
plt.savefig('gibbs.svg')

# %%
# Out:
# ['N = 1', 'N = 2', 'N = 10', 'N = 20', 'N = 100', 'N = 200']
